# %%
import requests
import json
import pandas as pd
import numpy as np
from pyspark.context import SparkContext
from pyspark.sql.session import SparkSession
from pyspark.sql.functions import json_tuple,from_json,get_json_object

# Initialize spark
sc = SparkContext('local')
spark = SparkSession(sc)

# %%
# Custom function

def get_Uruguay_Users(location,page,per_page):

    # In case we call the API on Github, we need to login 
    # headers = {"app_id": "c7f6d128",
    #           "app_key": "73ea2ed8109721300050137e74044fa6"}
    url = "https://api.github.com/search/users?q=location:{location}&page={page}&per_page={per_page}".format(location=location,page=page,per_page=per_page)
    print(url)
    response = requests.get(url, headers={})
    return response

# %%
# Initialize everything

res_per_page = 100
current_page = 1
response = get_Uruguay_Users("Uruguay", current_page, res_per_page)
# print(response.text)

resultlist_json = json.loads(response.text)
df_meta = pd.DataFrame.from_dict(resultlist_json, orient='index')
# print(df_meta)
uu_df = df_meta[0]
total_count = uu_df["total_count"]
frames = [pd.DataFrame(data=uu_df["items"])]
fetched = len(uu_df["items"])
# Out:
# https://api.github.com/search/users?q=location:Uruguay&page=1&per_page=100
# {"total_count":4020,"incomplete_results":false,"items":[{"login":"spastorino","id":52642,"node_id":"MDQ6VXNlcjUyNjQy","avatar_url":"https://avatars0.githubusercontent.com/u/52642?v=4","gravatar_id":"","url":"https://api.github.com/users/spastorino","html_url":"https://github.com/spastorino","followers_url":"https://api.github.com/users/spastorino/followers","following_url":"https://api.github.com/users/spastorino/following{/other_user}","gists_url":"https://api.github.com/users/spastorino/gists{/gist_id}","starred_url":"https://api.github.com/users/spastorino/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/spastorino/subscriptions","organizations_url":"https://api.github.com/users/spastorino/orgs","repos_url":"https://api.github.com/users/spastorino/repos","events_url":"https://api.github.com/users/spastorino/events{/privacy}","received_events_url":"https://api.github.com/users/spastorino/received_events","type":"User","site_admin":false,"score":1.0},{"login":"diegomura","id":5600341,"node_id":"MDQ6VXNlcjU2MDAzNDE=","avatar_url":"https://avatars1.githubusercontent.com/u/5600341?v=4","gravatar_id":"","url":"https://api.github.com/users/diegomura","html_url":"https://github.com/diegomura","followers_url":"https://api.github.com/users/diegomura/followers","following_url":"https://api.github.com/users/diegomura/following{/other_user}","gists_url":"https://api.github.com/users/diegomura/gists{/gist_id}","starred_url":"https://api.github.com/users/diegomura/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/diegomura/subscriptions","organizations_url":"https://api.github.com/users/diegomura/orgs","repos_url":"https://api.github.com/users/diegomura/repos","events_url":"https://api.github.com/users/diegomura/events{/privacy}","received_events_url":"https://api.github.com/users/diegomura/received_events","type":"User","site_admin":false,"score":1.0},{"login":"omab","id":91022,"node_id":"MDQ6VXNlcjkxMDIy","avatar_url":"https://avatars0.githubusercontent.com/u/91022?v=4","gravatar_id":"","url":"https://api.github.com/users/omab","html_url":"https://github.com/omab","followers_url":"https://api.github.com/users/omab/followers","following_url":"https://api.github.com/users/omab/following{/other_user}","gists_url":"https://api.github.com/users/omab/gists{/gist_id}","starred_url":"https://api.github.com/users/omab/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/omab/subscriptions","organizations_url":"https://api.github.com/users/omab/orgs","repos_url":"https://api.github.com/users/omab/repos","events_url":"https://api.github.com/users/omab/events{/privacy}","received_events_url":"https://api.github.com/users/omab/received_events","type":"User","site_admin":false,"score":1.0},{"login":"pablohoffman","id":185212,"node_id":"MDQ6VXNlcjE4NTIxMg==","avatar_url":"https://avatars1.githubusercontent.com/u/185212?v=4","gravatar_id":"","url":"https://api.github.com/users/pablohoffman","html_url":"https://github.com/pablohoffman","followers_url":"https://api.github.com/users/pablohoffman/followers","following_url":"https://api.github.com/users/pablohoffman/following{/other_user}","gists_url":"https://api.github.com/users/pablohoffman/gists{/gist_id}","starred_url":"https://api.github.com/users/pablohoffman/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/pablohoffman/subscriptions","organizations_url":"https://api.github.com/users/pablohoffman/orgs","repos_url":"https://api.github.com/users/pablohoffman/repos","events_url":"https://api.github.com/users/pablohoffman/events{/privacy}","received_events_url":"https://api.github.com/users/pablohoffman/received_events","type":"User","site_admin":false,"score":1.0},{"login":"lmgonzalves","id":12473993,"node_id":"MDQ6VXNlcjEyNDczOTkz","avatar_url":"https://avatars1.githubusercontent.com/u/12473993?v=4","gravatar_id":"","url":"https://api.github.com/users/lmgonzalves","html_url":"https://github.com/lmgonzalves"," ...

# %%
total_count
# Out:
# 4020

# %%
len(frames)
# Out:
# 10

# %%
fetched
# Out:
# 100

# %%
current_page
# Out:
# 11

# %%
# get all pages until there are none left
while (fetched < total_count) and (fetched < 1000):
    
    current_page += 1
    response = get_Uruguay_Users("Uruguay", current_page, res_per_page)

    # WE NEED TO MAKE A PROCEDURE (or related) FOR THIS
    resultlist_json = json.loads(response.text)
    df_meta = pd.DataFrame.from_dict(resultlist_json, orient='index')
    uu_df = df_meta[0]
    total_count = uu_df["total_count"]
    frames.append(pd.DataFrame(data=uu_df["items"]))
    fetched += len(uu_df["items"])

# %%
resultlist_json
# Out:
# {'message': 'Only the first 1000 search results are available',
#  'documentation_url': 'https://docs.github.com/v3/search/'}

# %%
result = pd.concat(frames)

# %%
result
# Out:
#             login        id               node_id  \
# 0      spastorino     52642      MDQ6VXNlcjUyNjQy
# 1       diegomura   5600341  MDQ6VXNlcjU2MDAzNDE=
# 2            omab     91022      MDQ6VXNlcjkxMDIy
# 3    pablohoffman    185212  MDQ6VXNlcjE4NTIxMg==
# 4     lmgonzalves  12473993  MDQ6VXNlcjEyNDczOTkz
# ..            ...       ...                   ...
# 95          gab3d  18104091  MDQ6VXNlcjE4MTA0MDkx
# 96       thepante  10443522  MDQ6VXNlcjEwNDQzNTIy
# 97    petralorena  20385504  MDQ6VXNlcjIwMzg1NTA0
# 98      agaleotti   6451595  MDQ6VXNlcjY0NTE1OTU=
# 99  grazianobolla  35064738  MDQ6VXNlcjM1MDY0NzM4
#
#                                            avatar_url gravatar_id  \
# 0   https://avatars0.githubusercontent.com/u/52642...
# 1   https://avatars1.githubusercontent.com/u/56003...
# 2   https://avatars0.githubusercontent.com/u/91022...
# 3   https://avatars1.githubusercontent.com/u/18521...
# 4   https://avatars1.githubusercontent.com/u/12473...
# ..                                                ...         ...
# 95  https://avatars2.githubusercontent.com/u/18104...
# 96  https://avatars2.githubusercontent.com/u/10443...
# 97  https://avatars3.githubusercontent.com/u/20385...
# 98  https://avatars0.githubusercontent.com/u/64515...
# 99  https://avatars3.githubusercontent.com/u/35064...
#
#                                            url  \
# 0      https://api.github.com/users/spastorino
# 1       https://api.github.com/users/diegomura
# 2            https://api.github.com/users/omab
# 3    https://api.github.com/users/pablohoffman
# 4     https://api.github.com/users/lmgonzalves
# ..                                         ...
# 95          https://api.github.com/users/gab3d
# 96       https://api.github.com/users/thepante
# 97    https://api.github.com/users/petralorena
# 98      https://api.github.com/users/agaleotti
# 99  https://api.github.com/users/grazianobolla
#
#                             html_url  \
# 0      https://github.com/spastorino
# 1       https://github.com/diegomura
# 2            https://github.com/omab
# 3    https://github.com/pablohoffman
# 4     https://github.com/lmgonzalves
# ..                               ...
# 95          https://github.com/gab3d
# 96       https://github.com/thepante
# 97    https://github.com/petralorena
# 98      https://github.com/agaleotti
# 99  https://github.com/grazianobolla
#
#                                         followers_url  \
# 0   https://api.github.com/users/spastorino/followers
# 1    https://api.github.com/users/diegomura/followers
# 2         https://api.github.com/users/omab/followers
# 3   https://api.github.com/users/pablohoffman/foll...
# 4   https://api.github.com/users/lmgonzalves/follo...
# ..                                                ...
# 95       https://api.github.com/users/gab3d/followers
# 96    https://api.github.com/users/thepante/followers
# 97  https://api.github.com/users/petralorena/follo...
# 98   https://api.github.com/users/agaleotti/followers
# 99  https://api.github.com/users/grazianobolla/fol...
#
#                                         following_url  \
# 0   https://api.github.com/users/spastorino/follow...
# 1   https://api.github.com/users/diegomura/followi...
# 2   https://api.github.com/users/omab/following{/o...
# 3   https://api.github.com/users/pablohoffman/foll...
# 4   https://api.github.com/users/lmgonzalves/follo...
# ..                                                ...
# 95  https://api.github.com/users/gab3d/following{/...
# 96  https://api.github.com/users/thepante/followin...
# 97  https://api.github.com/users/petralorena/follo...
# 98  https://api.github.com/users/agaleotti/followi...
# 99  https://api.github.com/users/grazianobolla/fol...
#
#                                             gists_url  \
# 0   https://api.github.com/users/spastorino/gists{...
# 1   https://api.github.com/users/diegomura/gists{/...
# 2   https://api.github.com/users/omab/gists{/gist_id}
# 3   https://api.github.com/users/pablohoffman/gist...
# 4   https://api.github.com/users/lmgonzalves/gists...
# ..                                                ...
# 95  https://api.github.com/users/gab3d/gists{/gist...
# 96  https://api.github.com/users/thepante/gists{/g...
# 97  https://api.github.com/users/petralorena/gists...
# 98  https://api.github.com/users/agaleotti/gists{/...
# 99  https://api.github.com/users/grazianobolla/gis...
#
#                                           starred_url  \
# 0   https://api.github.com/users/spastorino/starre...
# 1   https://api.github.com/users/diegomura/starred...
# 2   https://api.github.com/users/omab/starred{/own...
# 3   https://api.github.com/users/pablohoffman/star...
# 4   https://api.github.com/users/lmgonzalves/starr...
# ..                                                ...
# 95  https://api.github.com/users/gab3d/starred{/ow...
# 96  https://api.github.com/users/thepante/starred{...
# 97  https://api.github.com/users/petralorena/starr...
# 98  https://api.github.com/users/agaleotti/starred...
# 99  https://api.github.com/users/grazianobolla/sta...
#
#                                     subscriptions_url  \
# 0   https://api.github.com/users/spastorino/subscr...
# 1   https://api.github.com/users/diegomura/subscri...
# 2     https://api.github.com/users/omab/subscriptions
# 3   https://api.github.com/users/pablohoffman/subs...
# 4   https://api.github.com/users/lmgonzalves/subsc...
# ..                                                ...
# 95   https://api.github.com/users/gab3d/subscriptions
# 96  https://api.github.com/users/thepante/subscrip...
# 97  https://api.github.com/users/petralorena/subsc...
# 98  https://api.github.com/users/agaleotti/subscri...
# 99  https://api.github.com/users/grazianobolla/sub...
#
#                                   organizations_url  \
# 0      https://api.github.com/users/spastorino/orgs
# 1       https://api.github.com/users/diegomura/orgs
# 2            https://api.github.com/users/omab/orgs
# 3    https://api.github.com/users/pablohoffman/orgs
# 4     https://api.github.com/users/lmgonzalves/orgs
# ..                                              ...
# 95          https://api.github.com/users/gab3d/orgs
# 96       https://api.github.com/users/thepante/orgs
# 97    https://api.github.com/users/petralorena/orgs
# 98      https://api.github.com/users/agaleotti/orgs
# 99  https://api.github.com/users/grazianobolla/orgs
#
#                                            repos_url  \
# 0      https://api.github.com/users/spastorino/repos
# 1       https://api.github.com/users/diegomura/repos
# 2            https://api.github.com/users/omab/repos
# 3    https://api.github.com/users/pablohoffman/repos
# 4     https://api.github.com/users/lmgonzalves/repos
# ..                                               ...
# 95          https://api.github.com/users/gab3d/repos
# 96       https://api.github.com/users/thepante/repos
# 97    https://api.github.com/users/petralorena/repos
# 98      https://api.github.com/users/agaleotti/repos
# 99  https://api.github.com/users/grazianobolla/repos
#
#                                            events_url  \
# 0   https://api.github.com/users/spastorino/events...
# 1   https://api.github.com/users/diegomura/events{...
# 2   https://api.github.com/users/omab/events{/priv...
# 3   https://api.github.com/users/pablohoffman/even...
# 4   https://api.github.com/users/lmgonzalves/event...
# ..                                                ...
# 95  https://api.github.com/users/gab3d/events{/pri...
# 96  https://api.github.com/users/thepante/events{/...
# 97  https://api.github.com/users/petralorena/event...
# 98  https://api.github.com/users/agaleotti/events{...
# 99  https://api.github.com/users/grazianobolla/eve...
#
#                                   received_events_url  type  site_admin  score
# 0   https://api.github.com/users/spastorino/receiv...  User       False    1.0
# 1   https://api.github.com/users/diegomura/receive...  User       False    1.0
# 2   https://api.github.com/users/omab/received_events  User       False    1.0
# 3   https://api.github.com/users/pablohoffman/rece...  User       False    1.0
# 4   https://api.github.com/users/lmgonzalves/recei...  User       False    1.0
# ..                                                ...   ...         ...    ...
# 95  https://api.github.com/users/gab3d/received_ev...  User       False    1.0
# 96  https://api.github.com/users/thepante/received...  User       False    1.0
# 97  https://api.github.com/users/petralorena/recei...  User       False    1.0
# 98  https://api.github.com/users/agaleotti/receive...  User       False    1.0
# 99  https://api.github.com/users/grazianobolla/rec...  User       False    1.0
#
# [1000 rows x 19 columns]

# %%
result.to_csv('out.csv', index=False)

# %%
##############################################################
# SOME OTHER APPROACHES USED, BUT USING PANDA IS WAY SIMPLER #
##############################################################

# The response from the server has some metadata, 
# like the total users, so we need to transform the data before using it 
# uu_df = df[0]
# uruguayUsers_df = uu_df["items"]
# print(uruguayUsers_df)


# This was a test to mannualy parse everything
# def get_list(x):
#    o_list = []
#    for elt in x:
#        o_list.append(pd.DataFrame.from_dict(elt, orient='index'))
#    return o_list
#
# list_df = get_list(uruguayUsers_df)
# list_df

# This was a test to mannualy parse everything
# li = [[item.get('id'), item.get('login')] for item in uruguayUsers_df]
# li

# df = pd.DataFrame(data=uruguayUsers_df)
# df
